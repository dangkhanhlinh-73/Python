# %% [markdown]
# Bài tập 1: Viết một chương trình Python thực hiện các thao tác sau:
# 1. Nhập chuỗi từ do người dùng nhập vào, phân tách nhau bởi dấu phẩy
# 2. Tạo danh sách từ chuỗi nhập vào ở câu 1 được sắp xếp theo thứ tự bảng chữ cái. In ra màn hình các từ trên phân tách nhau bằng dấu phẩy.
# 3. Tạo danh sách từ chuỗi nhập vào ở câu 1, loại bỏ các từ bị trùng lặp, sau đó in ra màn hình chuỗi được sắp xếp theo thứ tự bảng chữ cái, các từ trên phân tách nhau bằng khoảng trắng.
# 4. Đếm số chữ cái và chữ số trong câu nhập từ câu 1.
# 5. Đếm chữ hoa, chữ thường trong câu nhập từ câu 1
# 6. Nhập chuỗi là các dòng được nhập vào, chuyển các dòng này thành chữ in hoa và in ra màn hình

# %%
def main():
    # Câu 1
    chuoi_nhap = input("Nhập chuỗi, phân tách bởi dấu phẩy: ")
    tu = chuoi_nhap.split(',')

    # Câu 2
    tu_sap_xep = sorted(tu)
    print("Danh sách sau khi sắp xếp: ", ', '.join(tu_sap_xep))

    # Câu 3
    tu_unic = list(set(tu))
    tu_unic_sap_xep = sorted(tu_unic)
    print("Danh sách sau khi loại bỏ trùng lặp và sắp xếp: ", ' '.join(tu_unic_sap_xep))

    # Câu 4
    so_chu_cai = sum(c.isalpha() for tu_1 in tu for c in tu_1)
    so_chu_so = sum(c.isdigit() for tu_1 in tu for c in tu_1)
    print(f"Số chữ cái: {so_chu_cai}, Số chữ số: {so_chu_so}")

    # Câu 5
    so_chu_hoa = sum(c.isupper() for tu_1 in tu for c in tu_1)
    so_chu_thuong = sum(c.islower() for tu_1 in tu for c in tu_1)
    print(f"Số chữ hoa: {so_chu_hoa}, Số chữ thường: {so_chu_thuong}")

    # Câu 6
    dong = chuoi_nhap.splitlines()
    dong_in_hoa = [line.upper() for line in dong]
    print("Chuỗi in hoa:")
    for line in dong_in_hoa:
        print(line)

if __name__ == "__main__":
    main()
# Out:
# Nhập chuỗi, phân tách bởi dấu phẩy: Bài tập123
# Danh sách sau khi sắp xếp:  Bài tập123
# Danh sách sau khi loại bỏ trùng lặp và sắp xếp:  Bài tập123
# Số chữ cái: 6, Số chữ số: 3
# Số chữ hoa: 1, Số chữ thường: 5
# Chuỗi in hoa:
# BÀI TẬP123
