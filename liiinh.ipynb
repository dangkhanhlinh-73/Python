# %%
thislist = [100, 50, 65, 82, 23]
def myfunc(x):
    return abs(x-50)
#kq: {50, 65, 23, 82, 100}
thislist.sort(key = myfunc)
thislist
# Out:
# [50, 65, 23, 82, 100]

# %%
ds = [('AV',84), ('KHTN',90), ('Toan',97), ('KHXH',82)]
ds.sort(key = lambda x: x[1])
ds
# Out:
# [('KHXH', 82), ('AV', 84), ('KHTN', 90), ('Toan', 97)]
